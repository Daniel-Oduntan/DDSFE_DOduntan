# %% [markdown]
# <a href="https://colab.research.google.com/github/Daniel-Oduntan/FDSfE_DOduntan/blob/main/HW2/Happiness.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
happiness=pd.read_csv('https://github.com/fedhere/FDSfE_FBianco/blob/main/data/happines.csv?raw=true')

# %%
happiness.head(10)
# Out:
#        Country                     Region  Happiness Score  Standard Error  \
# 0  Switzerland             Western Europe            7.587         0.03411
# 1      Iceland             Western Europe            7.561         0.04884
# 2      Denmark             Western Europe            7.527         0.03328
# 3       Norway             Western Europe            7.522         0.03880
# 4       Canada              North America            7.427         0.03553
# 5      Finland             Western Europe            7.406         0.03140
# 6  Netherlands             Western Europe            7.378         0.02799
# 7       Sweden             Western Europe            7.364         0.03157
# 8  New Zealand  Australia and New Zealand            7.286         0.03371
# 9    Australia  Australia and New Zealand            7.284         0.04083
#
#    Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# ...

# %% [markdown]
# Table above shows the top 10 rows of the table

# %%
happiness.tail(10)
# Out:
#           Country                           Region  Happiness Score  \
# 150   Ivory Coast               Sub-Saharan Africa            3.655
# 151  Burkina Faso               Sub-Saharan Africa            3.587
# 152   Afghanistan                    Southern Asia            3.575
# 153        Rwanda               Sub-Saharan Africa            3.465
# 154         Benin               Sub-Saharan Africa            3.340
# 155         Syria  Middle East and Northern Africa            3.006
# 156       Burundi               Sub-Saharan Africa            2.905
# 157          Togo               Sub-Saharan Africa            2.839
# 158       Namibia                              NaN            4.639
# 159        Gambia                              NaN            4.516
#
#      Standard Error  Economy (GDP per Capita)   Family  \
# 150         0.05141                   0.46534  0.77115
# 151         0.04324                   0.25812  0.85188
# ...

# %% [markdown]
# Table above shows the bottom 10 rows of the dataset

# %%
happiness.shape
# Out:
# (160, 12)

# %% [markdown]
# The Dataset has 160 rows and 12 columns

# %%
happiness.describe()
# Out:
#        Happiness Score  Standard Error  Economy (GDP per Capita)      Family  \
# count       160.000000      158.000000                160.000000  158.000000
# mean          5.365756        0.047885                  0.842979    0.991046
# std           1.141280        0.017146                  0.402840    0.272369
# min           2.839000        0.018480                  0.000000    0.000000
# 25%           4.517750        0.037268                  0.539453    0.856823
# 50%           5.203000        0.043940                  0.901085    1.029510
# 75%           6.193250        0.052300                  1.155523    1.214405
# max           7.587000        0.136930                  1.690420    1.402230
#
#        Health (Life Expectancy)     Freedom  Trust (Government Corruption)  \
# count                160.000000  160.000000                     160.000000
# mean                   0.628037    0.428151                       0.143023
# ...

# %% [markdown]
# The table above shows the statistical description of the dataset

# %%
happiness.isna().sum(axis=0)
# Out:
# Country                          0
# Region                           2
# Happiness Score                  0
# Standard Error                   2
# Economy (GDP per Capita)         0
# Family                           2
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                2
# year                             0
# dtype: int64

# %% [markdown]
# The list above displays the total number of null values in each column of the dataset

# %%
happiness.drop(['Region', 'Standard Error', 'Family', 'Dystopia Residual'], axis=1, inplace=True)

# %%
import missingno as msno
msno.matrix(happiness);

# %% [markdown]
# The colums with null values have been dropped according to the plot above

# %%
happiest_country=happiness[happiness['Happiness Score']==happiness['Happiness Score'].max()].Country.tolist()[0]

# %%
print('The happiest country is {}'.format(happiest_country))
# Out:
# The happiest country is Switzerland

# %%
happiness[happiness['Happiness Score']==happiness['Happiness Score'].max()]
# Out:
#        Country  Happiness Score  Economy (GDP per Capita)  \
# 0  Switzerland            7.587                   1.39651
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
#
#    Generosity  year
# 0     0.29678  2015

# %%
(happiness.groupby('Country').max().sort_values(by = 'Happiness Score', ascending = False)).head(10)
# Out:
#              Happiness Score  Economy (GDP per Capita)  \
# Country
# Switzerland            7.587                   1.39651
# Iceland                7.561                   1.30232
# Denmark                7.527                   1.32548
# Norway                 7.522                   1.45900
# Canada                 7.427                   1.32629
# Finland                7.406                   1.29025
# Netherlands            7.378                   1.32944
# Sweden                 7.364                   1.33171
# New Zealand            7.286                   1.25018
# Australia              7.284                   1.33358
#
#              Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# Country
# Switzerland                   0.94143  0.66557                        0.41978
# Iceland                       0.94784  0.62877                        0.14145
# Denmark                       0.87464  0.64938                        0.48357
# ...

# %% [markdown]
# The table above shows the list of the top 10 happiest countries

# %%
n_happiness_score=happiness[happiness['Country']=='Netherlands']['Happiness Score'].tolist()[0]
print('The happiness score for netherlands is {}')
# Out:
# 7.378

# %%
happiness.columns
# Out:
# Index(['Country', 'Happiness Score', 'Economy (GDP per Capita)',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'year'],
#       dtype='object')

# %%
happiness[['Happiness Score', 'Economy (GDP per Capita)', 'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
       'Generosity']].corr()
# Out:
#                                Happiness Score  Economy (GDP per Capita)  \
# Happiness Score                       1.000000                  0.780130
# Economy (GDP per Capita)              0.780130                  1.000000
# Health (Life Expectancy)              0.725936                  0.815719
# Freedom                               0.568437                  0.370565
# Trust (Government Corruption)         0.395285                  0.303545
# Generosity                            0.182865                 -0.013182
#
#                                Health (Life Expectancy)   Freedom  \
# Happiness Score                                0.725936  0.568437
# Economy (GDP per Capita)                       0.815719  0.370565
# Health (Life Expectancy)                       1.000000  0.361440
# Freedom                                        0.361440  1.000000
# Trust (Government Corruption)                  0.248882  0.492886
# ...

# %% [markdown]
# The table above shows the correlation between numerical values of the dataset

# %%
import pylab as pl

# %%
pl.imshow(happiness[['Happiness Score', 'Economy (GDP per Capita)', 'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
       'Generosity']].corr())
pl.xticks([0, 1, 2, 3, 4, 5],['Happiness Score', 'Economy (GDP per Capita)', 'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
       'Generosity'] )
pl.colorbar();

# %% [markdown]
# The plot above displays the correlation between the numerical values of the dataset
#
# The labellings of the axis look all clogged up because of the lenth of the names of the columns
#
# they are ; Happiness Score', 'Economy (GDP per Capita)', 'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity

# %%
(happiness.groupby('Country').max().sort_values(by = 'Generosity', ascending = False)).head(1)
# Out:
#          Happiness Score  Economy (GDP per Capita)  Health (Life Expectancy)  \
# Country
# Myanmar            4.307                   0.27108                   0.48246
#
#          Freedom  Trust (Government Corruption)  Generosity  year
# Country
# Myanmar  0.44017                        0.19034     0.79588  2015

# %% [markdown]
# The region with the highest generosity is Myanmar
