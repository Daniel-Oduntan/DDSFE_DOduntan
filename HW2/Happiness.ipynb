# %% [markdown]
# <a href="https://colab.research.google.com/github/Daniel-Oduntan/FDSfE_DOduntan/blob/main/HW2/Happiness.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
happiness=pd.read_csv('https://github.com/fedhere/FDSfE_FBianco/blob/main/data/happines.csv?raw=true')

# %%
happiness.head(10)
# Out:
#        Country  Happiness Score  Economy (GDP per Capita)  \
# 0  Switzerland            7.587                   1.39651
# 1      Iceland            7.561                   1.30232
# 2      Denmark            7.527                   1.32548
# 3       Norway            7.522                   1.45900
# 4       Canada            7.427                   1.32629
# 5      Finland            7.406                   1.29025
# 6  Netherlands            7.378                   1.32944
# 7       Sweden            7.364                   1.33171
# 8  New Zealand            7.286                   1.25018
# 9    Australia            7.284                   1.33358
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# 2                   0.87464  0.64938                        0.48357
# 3                   0.88521  0.66973                        0.36503
# 4                   0.90563  0.63297                        0.32957
# 5                   0.88911  0.64169                        0.41372
# 6                   0.89284  0.61576                        0.31814
# 7                   0.91087  0.65980                        0.43844
# 8                   0.90837  0.63938                        0.42922
# 9                   0.93156  0.65124                        0.35637
#
#    Generosity  year
# 0     0.29678  2015
# 1     0.43630  2015
# 2     0.34139  2015
# 3     0.34699  2015
# 4     0.45811  2015
# 5     0.23351  2015
# 6     0.47610  2015
# 7     0.36262  2015
# 8     0.47501  2015
# 9     0.43562  2015

# %%
happiness.tail(10)
# Out:
#           Country  Happiness Score  Economy (GDP per Capita)  \
# 150   Ivory Coast            3.655                   0.46534
# 151  Burkina Faso            3.587                   0.25812
# 152   Afghanistan            3.575                   0.31982
# 153        Rwanda            3.465                   0.22208
# 154         Benin            3.340                   0.28665
# 155         Syria            3.006                   0.66320
# 156       Burundi            2.905                   0.01530
# 157          Togo            2.839                   0.20868
# 158       Namibia            4.639                   0.87900
# 159        Gambia            4.516                   0.30800
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 150                   0.15185  0.46866                        0.17922
# 151                   0.27125  0.39493                        0.12832
# 152                   0.30335  0.23414                        0.09719
# 153                   0.42864  0.59201                        0.55191
# 154                   0.31910  0.48450                        0.08010
# 155                   0.72193  0.15684                        0.18906
# 156                   0.22396  0.11850                        0.10062
# 157                   0.28443  0.36453                        0.10731
# 158                   0.47700  0.40100                        0.05600
# 159                   0.42800  0.38200                        0.16700
#
#      Generosity  year
# 150     0.20165  2015
# 151     0.21747  2015
# 152     0.36510  2015
# 153     0.22628  2015
# 154     0.18260  2015
# 155     0.47179  2015
# 156     0.19727  2015
# 157     0.16681  2015
# 158     0.07000  2019
# 159     0.26900  2019

# %%
happiness.shape
# Out:
# (160, 12)

# %%
happiness.describe()
# Out:
#        Happiness Score  Standard Error  Economy (GDP per Capita)      Family  \
# count       160.000000      158.000000                160.000000  158.000000
# mean          5.365756        0.047885                  0.842979    0.991046
# std           1.141280        0.017146                  0.402840    0.272369
# min           2.839000        0.018480                  0.000000    0.000000
# 25%           4.517750        0.037268                  0.539453    0.856823
# 50%           5.203000        0.043940                  0.901085    1.029510
# 75%           6.193250        0.052300                  1.155523    1.214405
# max           7.587000        0.136930                  1.690420    1.402230
#
#        Health (Life Expectancy)     Freedom  Trust (Government Corruption)  \
# count                160.000000  160.000000                     160.000000
# mean                   0.628037    0.428151                       0.143023
# std                    0.246332    0.149803                       0.119492
# min                    0.000000    0.000000                       0.000000
# 25%                    0.437897    0.328630                       0.061067
# 50%                    0.695745    0.434635                       0.107220
# 75%                    0.809837    0.547057                       0.179565
# max                    1.025250    0.669730                       0.551910
#
#        Generosity  Dystopia Residual         year
# count  160.000000         158.000000   160.000000
# mean     0.236448           2.098977  2015.050000
# std      0.126605           0.553550     0.445805
# min      0.000000           0.328580  2015.000000
# 25%      0.148800           1.759410  2015.000000
# 50%      0.216130           2.095415  2015.000000
# 75%      0.307547           2.462415  2015.000000
# max      0.795880           3.602140  2019.000000

# %%
happiness.isna().sum(axis=0)
# Out:
# Country                          0
# Region                           2
# Happiness Score                  0
# Standard Error                   2
# Economy (GDP per Capita)         0
# Family                           2
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                2
# year                             0
# dtype: int64

# %%
happiness.drop(['Region', 'Standard Error', 'Family', 'Dystopia Residual'], axis=1, inplace=True)

# %%
import missingno as msno
msno.matrix(happiness);

# %% [markdown]
# The colums with null values have been dropped according to the table above

# %%
happiest_country=happiness[happiness['Happiness Score']==happiness['Happiness Score'].max()].Country.tolist()[0]

# %%
print('The happiest country is {}'.format(happiest_country))
# Out:
# The happiest country is Switzerland

# %%
happiness['Happiness Score'] == 'Switzerland'
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 155    True
# 156    True
# 157    True
# 158    True
# 159    True
# Name: Happiness Score, Length: 160, dtype: bool

# %%
happiness.groupby('Country').max().sort_values(by = 'Happiness Score', ascending = False)
# Out:
#             Happiness Score  Economy (GDP per Capita)  \
# Country
# Afghanistan     Switzerland                   0.31982
# Albania         Switzerland                   0.87867
# New Zealand     Switzerland                   1.25018
# Nicaragua       Switzerland                   0.59325
# Niger           Switzerland                   0.06940
# ...                     ...                       ...
# Guinea          Switzerland                   0.17417
# Haiti           Switzerland                   0.26673
# Honduras        Switzerland                   0.59532
# Hong Kong       Switzerland                   1.38604
# Zimbabwe        Switzerland                   0.27100
#
#              Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# Country
# Afghanistan                   0.30335  0.23414                        0.09719
# Albania                       0.81325  0.35733                        0.06413
# New Zealand                   0.90837  0.63938                        0.42922
# Nicaragua                     0.74314  0.55475                        0.19317
# Niger                         0.29707  0.47692                        0.15639
# ...                               ...      ...                            ...
# Guinea                        0.24009  0.37725                        0.12139
# Haiti                         0.38847  0.24425                        0.17175
# Honduras                      0.69510  0.40148                        0.06825
# Hong Kong                     1.01328  0.59608                        0.37124
# Zimbabwe                      0.33475  0.25861                        0.08079
#
#              Generosity  year
# Country
# Afghanistan     0.36510  2015
# Albania         0.14272  2015
# New Zealand     0.47501  2015
# Nicaragua       0.27815  2015
# Niger           0.19387  2015
# ...                 ...   ...
# Guinea          0.28657  2015
# Haiti           0.46187  2015
# Honduras        0.23027  2015
# Hong Kong       0.39478  2015
# Zimbabwe        0.18987  2015
#
# [160 rows x 7 columns]
